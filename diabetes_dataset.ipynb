# %% [markdown]
# <a href="https://colab.research.google.com/github/tanverrana/diabetes_dataset/blob/main/diabetes_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Bangladesh University/9th semester/pattern_recognation_lab/diabetes.csv")
array = dataset.values
X = array[:,1:8]
Y = array[:,8]

# %%
pca = PCA().fit(X)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.grid(axis = "x")
plt.grid(axis = "y")
plt.xlabel('Number of Components')
plt.ylabel('variance')
# Out:
# Text(0, 0.5, 'variance')

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
lda = LDA(n_components =1).fit_transform(X,Y)
print(lda)
# Out:
# [[ 1.44904999e+00]
#  [-1.33726833e+00]
#  [ 1.37831578e+00]
#  [-1.61637536e+00]
#  [ 2.50802554e+00]
#  [-7.77329744e-01]
#  [-1.37254719e+00]
#  [ 5.02793548e-01]
#  [ 1.88686564e+00]
#  [-1.67462245e+00]
#  [-3.99297050e-01]
#  [ 1.73400582e+00]
#  [ 1.39672827e+00]
#  [ 1.75118776e+00]
#  [ 1.28208994e+00]
#  [ 6.83077525e-02]
#  [ 4.78689934e-01]
#  [-7.17444975e-01]
#  [ 4.37247575e-01]
#  [-1.59550846e-02]
#  [ 2.36514889e-01]
#  [-9.02376744e-02]
#  [ 2.57745515e+00]
#  [-5.09268075e-01]
#  [ 9.10920351e-01]
#  [ 5.65855422e-02]
#  [ 1.28609299e+00]
#  [-1.51871476e+00]
#  [ 3.85112445e-01]
#  [-1.15117137e-01]
#  [ 7.04880948e-01]
#  [ 8.73826293e-01]
#  [-1.64263599e+00]
#  [-2.03835555e+00]
#  [ 9.26346785e-02]
#  [-6.78017634e-01]
#  [ 5.46652477e-01]
#  [ 2.01275768e-02]
#  [-5.07541362e-01]
#  [ 1.10473259e+00]
#  [ 1.48985221e+00]
#  [ 9.85474458e-01]
#  [-9.01491424e-01]
#  [ 2.33202625e+00]
#  [ 9.46156535e-01]
#  [ 3.04590313e+00]
#  [ 6.92198846e-01]
# ...

# %%
# !pip install pymrmr
import pymrmr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 69 kB 6.7 MB/s
# ...
#   Created wheel for pymrmr: filename=pymrmr-0.1.11-cp37-cp37m-linux_x86_64.whl size=276658 sha256=1009df6e69f989565a9419bd527fe0a2f13245882c046037698b7ec36896d1b8
#   Stored in directory: /root/.cache/pip/wheels/81/95/66/05731ac334bc74a1251a727af18eb28dc027217ee817a0cab6
# Successfully built pymrmr
# ...

# %%
p= pymrmr.mRMR(dataset, 'MIQ',4)
print(p)
# Out:
# ['Glucose', 'Insulin', 'Age', 'BloodPressure']
